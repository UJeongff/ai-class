# %% [markdown]
# ### 1. PCA를 이용해서 diabates 적용해보기

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
# DSA 데이터 로드
dsa_data = pd.read_csv(r'C:\Users\dnwjd\OneDrive\Desktop\CSE_6\딥러닝\DSA_features.csv')

# %%
# 사용할 특성(features) 선택 (예: T_xacc_mean, T_yacc_mean 등)
features = ['T_xacc_mean', 'T_yacc_mean', 'T_xacc_var', 'T_yacc_std', 
            'T_yacc_var', 'LL_xacc_mean', 'LL_yacc_mean', 'LL_zmag_mean']  # 원하는 특성으로 변경 가능

# %%
# 선택한 특성으로 데이터프레임 생성
X = dsa_data[features]

# %%
# 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# PCA 적용
pca = PCA(n_components=2)  # 2차원으로 축소
X_pca = pca.fit_transform(X_scaled)

# %%
# 결과 시각화
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], alpha=0.5)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of DSA Dataset')
plt.grid()
plt.show()

# %% [markdown]
# ### 2. Autoencoder(AE)를 활용한 이상 탐지 실습

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.metrics import accuracy_score

# %%
# 1. 데이터 로드
data = pd.read_csv(r"C:\Users\dnwjd\OneDrive\Desktop\CSE_6\딥러닝\DSA_features.csv")

# %%
# 2. lying, jumping 데이터 분리 (activity 열 사용)
lying_data = data[(data['activity'] == 'lyingRigh') | (data['activity'] == 'lyingBack')]
jumping_data = data[data['activity'] == 'jumping']

# %%
# 3. 훈련용 데이터 (lying 데이터만 사용)
X_train = lying_data.drop(['activity', 'people'], axis=1).values

# %%
# 4. 테스트용 데이터 (lying과 jumping 섞음)
X_test = pd.concat([lying_data, jumping_data]).drop(['activity', 'people'], axis=1).values
y_test = pd.concat([lying_data, jumping_data])['activity'].apply(lambda x: 0 if 'lying' in x else 1).values  # 0: 정상, 1: 비정상

# %%
# 5. 데이터 정규화
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# 6. Autoencoder 모델 구축
input_dim = X_train_scaled.shape[1]
input_layer = Input(shape=(input_dim,))
encoded = Dense(64, activation='relu')(input_layer)
encoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# %%
# 7. Autoencoder 훈련 (lying 데이터만으로)
autoencoder.fit(X_train_scaled, X_train_scaled, epochs=50, batch_size=32, shuffle=True)
# Out:
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.1390
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2424
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0081
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9907
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8344
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8196
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1033
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6752
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7910
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6885
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8689
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8647
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7304
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0040
# Epoch 15/50
# ...

# %%
# 8. 테스트 데이터로 Reconstruction Error 계산
reconstructed = autoencoder.predict(X_test_scaled)
reconstruction_error = np.mean(np.power(X_test_scaled - reconstructed, 2), axis=1)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# 9. 적절한 Threshold 설정 (여기서는 임의로 정함, 필요 시 조정)
threshold = np.percentile(reconstruction_error, 95)

# %%
# 10. Threshold에 따른 비정상 데이터 분류
y_pred = [1 if error > threshold else 0 for error in reconstruction_error]

# %%
# 11. Accuracy 계산
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Accuracy: 71.67%
